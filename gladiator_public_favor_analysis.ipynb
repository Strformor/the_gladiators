# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Read the csv file and list top 5 rows of data
gladitor_df = pd.read_csv("gladiator_data.csv")


gladitor_df.head()
# Out:
#                Name  Age  Birth Year    Origin  Height  Weight     Category  \
# 0  Novellius Probus   21          29      Gaul     180      74  Hoplomachus
# 1      Baebius Geta   36          14   Numidia     174      80       Thraex
# 2    Rufius Gordian   29          21  Germania     157      94  Hoplomachus
# 3    Pettius Appius   21          29    Greece     177      72       Thraex
# 4  Clodius Fundanus   26          24      Rome     178     104   Provocator
#
#    Wins  Losses Special Skills  ... Battle Experience Psychological Profile  \
# 0     4       1         Novice  ...                 5               Fearful
# 1    10       2         Novice  ...                12               Fearful
# 2     6       2          Speed  ...                 8            Aggressive
# 3     7       1        Tactics  ...                 8                 Stoic
# 4     5       0         Novice  ...                 5           Calculative
#
#   Health Status  Personal Motivation Previous Occupation  Training Intensity  \
# 0     Excellent            Vengeance            Criminal              Medium
# 1     Excellent              Freedom         Entertainer              Medium
# 2     Excellent                Glory          Unemployed              Medium
# 3     Excellent                Glory             Laborer              Medium
# 4     Excellent               Wealth         Entertainer              Medium
#
#   Battle Strategy Social Standing Crowd Appeal Techniques  Survived
# 0        Balanced             Low                  Humble     False
# 1        Balanced          Medium             Charismatic      True
# 2      Aggressive          Medium             Charismatic      True
# 3      Aggressive          Medium             Charismatic      True
# 4      Aggressive             Low            Intimidating      True
#
# [5 rows x 29 columns]

# %%
# List the details of the data in the columns
gladitor_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 107464 entries, 0 to 107463
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Name                     107464 non-null  object
#  1   Age                      107464 non-null  int64
#  2   Birth Year               107464 non-null  int64
#  3   Origin                   107464 non-null  object
#  4   Height                   107464 non-null  int64
#  5   Weight                   107464 non-null  int64
#  6   Category                 107464 non-null  object
#  7   Wins                     107464 non-null  int64
#  8   Losses                   107464 non-null  int64
#  9   Special Skills           107464 non-null  object
#  10  Weapon of Choice         107464 non-null  object
#  11  Patron Wealth            107464 non-null  object
#  12  Equipment Quality        107464 non-null  object
#  13  Public Favor             107464 non-null  float64
#  14  Injury History           107464 non-null  object
#  15  Mental Resilience        107464 non-null  float64
#  16  Diet and Nutrition       107464 non-null  object
#  17  Tactical Knowledge       107464 non-null  object
#  18  Allegiance Network       107464 non-null  object
#  19  Battle Experience        107464 non-null  int64
#  20  Psychological Profile    107464 non-null  object
#  21  Health Status            107464 non-null  object
#  22  Personal Motivation      107464 non-null  object
#  23  Previous Occupation      107464 non-null  object
#  24  Training Intensity       107464 non-null  object
#  25  Battle Strategy          107464 non-null  object
#  26  Social Standing          107464 non-null  object
#  27  Crowd Appeal Techniques  107464 non-null  object
#  28  Survived                 107464 non-null  bool
# dtypes: bool(1), float64(2), int64(7), object(19)
# memory usage: 23.1+ MB

# %% [markdown]
# ## Question 1 - Can public favor be predicted from attributes such as crowd appeal techniques and social standing?

# %%
# Drop the rows with none values, and sort the data in ascending order of "Public Favor"
# And assign top 10 "Public Favor" rows to dataframe.

gladitor_df.dropna(inplace=True)

gladitor_df = gladitor_df.sort_values(by="Public Favor", ascending=False)

# Pick top 10 with highest public favor ratings.
gladitor_df = gladitor_df.head(10)

# List top 10 Public Favor rows/data
gladitor_df
# Out:
#                      Name  Age  Birth Year   Origin  Height  Weight  \
# 55550    Salinator Justus   45          61     Gaul     171      77
# 37052  Laecanius Lacerius   42          42  Numidia     202      73
# 41006  Numonius Crispinus   35          53   Thrace     173      90
# 73589       Manius Dacian   42          93  Numidia     162      87
# 35491    Sedatius Fannius   45          37   Thrace     173      69
# 7119   Cornelius Albinius   45          10   Greece     167      75
# 35426     Ovidius Cispius   45          37     Gaul     193      85
# 3049   Statilius Valerius   33          19     Gaul     168      84
# 31171   Ogulnius Cominius   41          37   Greece     157      56
# 97961      Foslius Julius   27         183     Rome     178      85
#
#          Category  Wins  Losses Special Skills  ... Battle Experience  \
# 55550    Murmillo    14       3       Strength  ...                17
# 37052  Provocator    11       1        Agility  ...                12
# 41006     Secutor    13       1         Novice  ...                14
# 73589      Thraex    11       1          Speed  ...                12
# 35491      Thraex    14       2      Endurance  ...                16
# 7119     Murmillo    15       2        Agility  ...                17
# 35426    Murmillo    11       1         Novice  ...                12
# 3049       Thraex    13       3          Speed  ...                16
# 31171  Provocator    17       3        Tactics  ...                20
# 97961      Thraex     9       0      Endurance  ...                 9
#
#       Psychological Profile Health Status  Personal Motivation  \
# 55550                 Stoic          Good             Survival
# 37052           Calculative          Fair                Glory
# 41006               Fearful     Excellent             Survival
# 73589           Calculative          Good             Survival
# 35491               Fearful          Good               Wealth
# 7119            Calculative          Fair              Freedom
# 35426                 Stoic          Good              Freedom
# 3049                Fearful          Good             Survival
# 31171           Calculative          Good                Glory
# 97961                 Stoic     Excellent               Wealth
#
#       Previous Occupation  Training Intensity Battle Strategy Social Standing  \
# 55550          Unemployed              Medium      Aggressive            High
# 37052             Laborer              Medium        Balanced            High
# 41006          Unemployed                 Low        Balanced          Medium
# 73589            Criminal              Medium        Balanced          Medium
# 35491             Laborer              Medium      Aggressive          Medium
# 7119          Entertainer                 Low        Balanced          Medium
# 35426          Unemployed                 Low      Aggressive             Low
# 3049             Criminal              Medium        Balanced            High
# 31171         Entertainer                 Low       Defensive          Medium
# 97961             Laborer              Medium        Balanced          Medium
#
#       Crowd Appeal Techniques  Survived
# 55550              Flamboyant      True
# 37052             Charismatic      True
# 41006                  Humble      True
# 73589              Flamboyant     False
# 35491            Intimidating      True
# 7119             Intimidating     False
# 35426                  Humble      True
# 3049               Flamboyant      True
# 31171             Charismatic      True
# 97961            Intimidating      True
#
# [10 rows x 29 columns]

# %%
# Visualize "Public Favor" vs other factors which are Str obj values
plt.rcParams["figure.figsize"] = (11, 8)
plt.rcParams["figure.autolayout"] = True

# Battle Strategy vs Public Favor plot
plt.plot(
    gladitor_df["Public Favor"],
    gladitor_df["Battle Strategy"],
    "-o",
    label="Battle Strategy",
)

# Category vs Public Favor plot
plt.plot(
    gladitor_df["Public Favor"],
    gladitor_df["Category"],
    "-o",
    label="Category",
)

# Special Skills vs Public Favor plot
plt.plot(
    gladitor_df["Public Favor"],
    gladitor_df["Special Skills"],
    "-o",
    label="Special Skills",
)

# Crowd Appeal Techniques vs Public Favor plot
plt.plot(
    gladitor_df["Public Favor"],
    gladitor_df["Crowd Appeal Techniques"],
    "-o",
    label="Crowd Appeal Techniques",
)

# Psychological Profile vs Public Favor plot
plt.plot(
    gladitor_df["Public Favor"],
    gladitor_df["Psychological Profile"],
    "-o",
    label="Psychological Profile",
)

# Social Standing vs Public Favor plot
plt.plot(
    gladitor_df["Public Favor"],
    gladitor_df["Social Standing"],
    "-o",
    label="Social Standing",
)

# Patron Wealth vs Public Favor plot
plt.plot(
    gladitor_df["Public Favor"],
    gladitor_df["Patron Wealth"],
    "-o",
    label="Patron Wealth",
)


plt.legend(bbox_to_anchor=(0.75, 1.0), loc="best")
plt.title("Public Favor vs Other Factors")
plt.xlabel("Public Favor")
plt.tight_layout()
plt.show()

# %%
# Visualize "Publi Favor" vs "Wins" & "Battle Experience" factors which are int values

plt.rcParams["figure.figsize"] = (7, 3.5)
plt.rcParams["figure.autolayout"] = True

# Wins vs Public Favor plot
plt.plot(
    gladitor_df["Public Favor"],
    gladitor_df["Wins"],
    "-o",
    label="Wins",
)

# Battle Experience vs Public Favor plot
plt.plot(
    gladitor_df["Public Favor"],
    gladitor_df["Battle Experience"],
    "-o",
    label="Battle Experience",
)

# Age vs Public Favor plot
plt.plot(
    gladitor_df["Public Favor"],
    gladitor_df["Age"],
    "-o",
    label="Age",
)

plt.legend(bbox_to_anchor=(0.71, 1.0), loc="best")
plt.title("Public Favor vs Other Factors")
plt.xlabel("Public Favor")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Answer to the question, Can public favor be predicted from attributes such as crowd appeal techniques and social standing ?
# ### Non of the factors infulence the Public Favor
